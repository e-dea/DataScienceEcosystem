# %% [markdown]
# <a href="https://colab.research.google.com/github/e-dea/DataScienceEcosystem/blob/main/Copy_of_PythonwithSalvatore2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ciao Francesca se vuoi qui ti insegno un po di Python
#
# Prima di tutto impariamo ad importore drive cosi poi possiamo caricare file.
# nel primo esempio usiamo la cartella di cola
#  simple_data . anche qui puoi salvare momentaneamente (almeno era cosi fino a poco tempo fa) quando chiudi perdi il lavoro.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ora tramite una libreria (sarà quasi sempre cosi , cerchi una libreria che faccia quel che ti serve e la importi) carichiaom un file e andiamo a leggerlo.
# vedi una prima cosa importante: il commento nel codice che verra ignorato dal compilatore in fase di esecuzione. il commento inizia con un  carattere speciale # tutto quello alla destra di quel simbolo verrà ignrato e quindi servirà a te per scriverti commenti

# %%
import pandas as pd

# Sostituisci con il percorso del tuo file
file_path = '/content/sample_data/california_housing_test.csv'

# Carica i dati in un DataFrame di pandas
df = pd.read_csv(file_path)

# Mostra le prime righe del DataFrame per confermare il caricamento
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# Posso mostrare anche l'intero documento, ma essendo grande mi mostrerà solo inizio fine.
print(df)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# come primo esercizio cerca il modo di mostrare di seguito le righe da 1000
# a 1030

# %%
print(df[1000:1031])
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1000    -119.75     34.40                31.0       1997.0           299.0
# 1001    -120.94     39.32                14.0       3120.0           595.0
# 1002    -117.68     35.61                 9.0       4241.0           832.0
# 1003    -122.27     38.12                45.0       4423.0          1001.0
# 1004    -118.21     34.11                32.0       2759.0           499.0
# 1005    -117.23     33.10                 4.0       1862.0           291.0
# 1006    -119.46     35.14                30.0       2943.0           697.0
# 1007    -119.78     36.76                50.0       1343.0           322.0
# 1008    -117.81     33.66                20.0       2851.0           490.0
# 1009    -119.29     34.31                25.0       1092.0           190.0
# 1010    -122.41     37.61                46.0       2975.0           643.0
# ...

# %% [markdown]
# Ihihih done :) :) :)

# %% [markdown]
# Ben Brava francesca, andiamo subito a fare un po di analisi e visualizzazioni.
# **Visualizzare la Distribuzione del Valore Mediano dell'Abitazione**
# Se vuoi visualizzare la distribuzione del valore mediano dell'abitazione, potresti utilizzare una libreria di visualizzazione come matplotlib o seaborn. Importante: ricorda che se vai offline devi ricompilare il codice sopra, almeno quello che poi ti serve, per esempio la variabile df contiene i dati, ma solo perché carichiamo i dati nel codice sopra. è qualcosa da tenere presente in Python anche perché si tratta di un **linguaggio interpretato** . esistono due tipi di linguaggi di programmazione: compilati e interpretati. nel primo caso il codice viene compialto da un programma compilatore che poi lo esegue tutto insieme  (molto veloce c, c++ , java etc) , e linguaggi interpretati, cioe compilati riga per riga dal comilatore mentre legge il codice. molto piu lento ma ha altri vantaggi, come per esempio sono flessibili e meno complicati come python

# %% [markdown]
# Molto interessante, non sapevo la differenza. :)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizza la distribuzione del valore mediano dell'abitazione
sns.histplot(df['median_house_value'], kde=True)
plt.title('Distribuzione del Valore Mediano dell\'Abitazione')
plt.xlabel('Valore Mediano dell\'Abitazione')
plt.ylabel('Frequenza')
plt.show()

# %% [markdown]
# come vedi importi librerie e poi le usi. questo lavoro che viene fatto ogni giorno dagli sviluppatori. trovare una libreria usata e affidabile e utilizzare metodi pronti. è  la potenza del liguaggio ad oggetti che te lo permette.

# %% [markdown]
# tu farai questo esercizio su questi dati: Analizzare la Relazione tra Reddito Mediano e Valore Mediano dell'Abitazione
# Potresti voler esplorare come il reddito mediano influisce sul valore mediano dell'abitazione utilizzando un grafico scatter. (ti cerchi cosa vuol dire e lo fai) non usare bot AI prova a fare una ricerca

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

x = (df.iloc[:, 7])
y = (df.iloc[:, 8])

# Visualizza il grafico a dispersione

plt.scatter(x, y)

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg=1 means linear fit (i.e. polynomial of degree 1)

b, a = np.polyfit(x, y, deg=1)

#plt.plot(x, y, '.')
# Plot regression line

plt.plot(x, a + b * x, color="k", lw=2.5);

#creare e plottare coefficiente di correlazione e p value

r, p = stats.pearsonr(x, y)
plt.annotate('r = {:.2f}'.format(r), xy=(0.7, 0.9), xycoords='axes fraction')
plt.title('Relazione tra il Valore Mediano dell\'Abitazione e il Valore mediano di reddito')
plt.xlabel('Valore mediano di reddito')
plt.ylabel('Valore Mediano dell\'Abitazione')
plt.show()

print('p = '"%f" % p)
# Out:
# p = 0.000000

# %% [markdown]
# L'associazione tra le due variabili è significativa :)
# Qui sotto con seaborn, senza fit line sembrava più carino

# %%
sns.scatterplot(x="median_income", y="median_house_value", data=df)
sns.lmplot(x="median_income", y="median_house_value", data=df)
plt.title('Relazione tra il Valore Mediano dell\'Abitazione e il Valore mediano di reddito')
plt.xlabel('Valore mediano di reddito')
plt.ylabel('Valore Mediano dell\'Abitazione')
plt.show()
